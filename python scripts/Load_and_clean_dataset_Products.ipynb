# %%
import numpy as np
import pandas as pd
from unidecode import unidecode
import re
import string
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load Ingredients

# %%
relative_path = '../Data/raw/_Product__RAW_Data.xlsx'
org_products = pd.read_excel(relative_path)
products = org_products.copy()

display(products)
# Out:
#              Barcode     Unnamed: 1  \
# 0      3600542399326  3600542399326
# 1      8606029266766  8606029266766
# 2      4049639429550  4049639429550
# 3      4011700740291  4011700740291
# 4      4011700740475  4011700740475
# ...              ...            ...
# 13670  6001051004959  6001051004959
# 13671  5060447940494  5060447940494
# 13672  4005900870407  4005900870407
# 13673  8436575091013  8436575091013
# 13674  8436575091013  8436575091013
#
#                                          Ingredient List  \
# 0      Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 1                                               Silicone
# 2      aqua (water),stearic acid,copernicia cerifera ...
# 3      butane,alcohol,propane,parfum (fragrance),dipr...
# 4      sodium palmate,sodium palm kernelate,aqua (wat...
# ...                                                  ...
# 13670  Aqua, Alcohol Denat., Butyl Methoxydibenzoylme...
# 13671  Aqua (Water), Octocrylene, Alcohol Denat., Gly...
# 13672  ALPHA-ISOMETHYL IONONE, *******, BUTYL METHOXY...
# 13673  AQUA (WATER), CUCUMIS SATIVUS (CUCUMBER）FRUIT ...
# 13674  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
#
#                                                     Name
# 0      Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 1                            Velnea Fingering Silik.Lila
# 2      Magic Finish 5-In-1 Hybrid Mascara\nVolume, Le...
# 3      Echt Kï¿½Lnisch Wasser Aerosol Deodorant Spray...
# 4      Echt Kï¿½Lnisch Wasser Cream Soap\nMildly Clea...
# ...                                                  ...
# 13670          Sun Babies & Kids Kids' Sun Spray Spf 50+
# 13671                                   Sun Cream Spf 30
# 13672                Sun Oil Spray Tropical Bronze Spf 6
# 13673                                      Retinol Cream
# 13674                                                NaN
#
# [13675 rows x 4 columns]

# %% [markdown]
# ### Clean DataSet

# %%
def clean_text(s):
    if isinstance(s, str):
        s = unidecode(s)    # è -> e (unicode transliteration)
        s = s.lower()
        return s

# %%
def unidecode_text(s):      # function for product_name only
    if isinstance(s, str):
        s = unidecode(s)    # è -> e (unicode transliteration)
        return s

# %%
products = products.drop(columns='Unnamed: 1')
products.rename(columns={'Ingredient List': 'ingredient_list_original'}, inplace=True)
products.rename(columns={'Name': 'product_name'}, inplace=True)
products['ingredient_list'] = products['ingredient_list_original'].apply(clean_text)

ingredients_pattern = r'^(?i)ingredients[^\w\s]*:$'     # brisenje na stringot ingredients: sto se srekjava na pocetok na nekoj od listite so sostojki
products['ingredient_list'] = products['ingredient_list'].str.replace(ingredients_pattern, '')
products['ingredient_list'] = products['ingredient_list'].str.replace('f,i,l,', 'fil')
products.reset_index(drop=True, inplace=True)

# %%
products['product_name'] = products['product_name'].apply(unidecode_text)
search_string = re.escape(', *******')                                                                      # brisenje na sting so '******' koj se srekjava
products['ingredient_list'] = products['ingredient_list'].str.replace(search_string, '')
#products['ingredient_list'] = products['ingredient_list'].str.replace('.', '')                             # mislam ne treba oti ima brojki so tocka odvoeni kako procenti
products['ingredient_list'] = products['ingredient_list'].str.split(", ")

products = products.explode('ingredient_list')
products.reset_index(drop=True, inplace=True)

# %%
patterns_to_replace = patterns_to_replace = ['[+/-]:', '[+/-:', '[+ -]', '[+/-', '(+ - ', '(+ / -)', '(+/-)', '(+/', '[ + / -', '[ +(', '[ +/-', '[+  -', '[+ -', '[+ / -', '[+ -', '[+(', '[+/-]', '[+/-', '[+/- ', '+/- ['] 
for pattern in patterns_to_replace: 
    products['ingredient_list'] = products['ingredient_list'].str.replace(re.escape(pattern), '') # brisenje na tekstot na sostojki sto pocnuvaat so: '+/-' ili '[+ -' ili '[+/- ' ime na sostojka

products = products.dropna(subset=['ingredient_list']).loc[products['ingredient_list'] != '']

# %%
products = products[~(products['ingredient_list'].astype(str).str.contains('may contain', case=False, regex=False) | (products['ingredient_list'].isna()))]      # brisenje na redot na sostojki sto pocnuvaat sto sodrzat: may contain

products = products[~products['ingredient_list'].astype(str).str.match(r'^[0-9.,-]+$')]                     # brisenje na red koj sodrzi samo broj + punktuacija
products = products[~products['ingredient_list'].astype(str).str.match(r'^[^\w\s]+[0-9]+$')]                # brisenje na red koj sodrzi samo punktuacija + broj
products['ingredient_list'] = products['ingredient_list'].str.lstrip(',')                                   # brisenje na ',' ako stringot pocnuva so ','
products = products[~products['ingredient_list'].str.strip(string.punctuation).eq('')]                      # brisenje na red koj sodrzi samo punktuacija
products = products[~products['ingredient_list'].apply(lambda x: pd.to_numeric(x, errors='coerce')).notna() | (products['ingredient_list'] == '')]  # brisenje na red koj sodrzi samo broj
products['ingredient_list'] = products['ingredient_list'].astype(str).str.replace('*', '')                  # brisenje na dzvezdicki
products['ingredient_list'] = products['ingredient_list'].str.rstrip(string.punctuation)                    # brisenje punktuacija na kraj na sting
products['ingredient_list'] = products['ingredient_list'].str.strip()                                       # trim

# %%
mask_to_drop = (products['ingredient_list'].str.len() < 3) | (products['ingredient_list'].str.len() > 70)   # brisenje na red koj sodrzi pomalku od 3 ili povekje od 70 karakteri
products = products[~mask_to_drop]

# %%
nan_rows = products['ingredient_list'].isna()
print(nan_rows.sum())
products = products.dropna(subset=['ingredient_list'])

nan_rows = products['ingredient_list'].isna()
print(nan_rows.sum())
# Out:
# 0
# 0

# %%
products
# Out:
#               Barcode                           ingredient_list_original  \
# 0       3600542399326  Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 1       3600542399326  Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 2       3600542399326  Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 3       3600542399326  Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 4       3600542399326  Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# ...               ...                                                ...
# 236715  8436575091013  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
# 236716  8436575091013  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
# 236717  8436575091013  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
# 236718  8436575091013  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
# 236719  8436575091013  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
#
#                                              product_name  \
# 0       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 1       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 2       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 3       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 4       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# ...                                                   ...
# 236715                                               None
# 236716                                               None
# 236717                                               None
# 236718                                               None
# 236719                                               None
#
#                                           ingredient_list
# 0                                            aqua / water
# 1                                  aluminum chlorohydrate
# 2                                        cetearyl alcohol
# 3                                            ceteareth-33
# 4                                      parfum / fragrance
# ...                                                   ...
# 236715               6,10-dimethylundeca-1,5,9-trien-4-ol
# 236716                                   6-amino-m-cresol
# 236717                                6,7-dihydrolinalool
# 236718                                    6-hydroxyindole
# 236719  1,2,3,4,4a,7,8,8a-octahydro-2,4a,5,8a-tetramet...
#
# [228240 rows x 4 columns]

# %%
#products.to_excel('products.xlsx')

# %%
# org_products = pd.read_excel('../Data/products.xlsx')
# products = org_products.copy()

# display(products)

# %%
nan_rows = products['ingredient_list'].isna()
print(nan_rows.sum())
products = products.dropna(subset=['ingredient_list'])

nan_rows = products['ingredient_list'].isna()
print(nan_rows.sum())
# Out:
# 0
# 0

# %%
products.to_excel('../Data/products.xlsx')

# %%
# org_products = pd.read_excel('../Data/products.xlsx')
# products = org_products.copy()

# display(products)
# Out:
#         Unnamed: 0        Barcode  \
# 0                0  3600542399326
# 1                1  3600542399326
# 2                2  3600542399326
# 3                3  3600542399326
# 4                4  3600542399326
# ...            ...            ...
# 228235      236715  8436575091013
# 228236      236716  8436575091013
# 228237      236717  8436575091013
# 228238      236718  8436575091013
# 228239      236719  8436575091013
#
#                                  ingredient_list_original  \
# 0       Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 1       Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 2       Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 3       Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# 4       Aqua / Water, Aluminum Chlorohydrate, Cetearyl...
# ...                                                   ...
# 228235  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
# 228236  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
# 228237  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
# 228238  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
# 228239  2-Ethyl-3,(5 Or 6)-Dimethylpyrazine, 2-Trans, ...
#
#                                              product_name  \
# 0       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 1       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 2       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 3       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# 4       Garnier Mineral Hyaluronic Care 72H Deodorant ...
# ...                                                   ...
# 228235                                                NaN
# 228236                                                NaN
# 228237                                                NaN
# 228238                                                NaN
# 228239                                                NaN
#
#                                           ingredient_list
# 0                                            aqua / water
# 1                                  aluminum chlorohydrate
# 2                                        cetearyl alcohol
# 3                                            ceteareth-33
# 4                                      parfum / fragrance
# ...                                                   ...
# 228235               6,10-dimethylundeca-1,5,9-trien-4-ol
# 228236                                   6-amino-m-cresol
# 228237                                6,7-dihydrolinalool
# 228238                                    6-hydroxyindole
# 228239  1,2,3,4,4a,7,8,8a-octahydro-2,4a,5,8a-tetramet...
#
# [228240 rows x 5 columns]

# %%
# nan_rows = products['ingredient_list'].isna()
# print(nan_rows.sum())
# products = products.dropna(subset=['ingredient_list'])

# nan_rows = products['ingredient_list'].isna()
# print(nan_rows.sum())
# Out:
# 9
